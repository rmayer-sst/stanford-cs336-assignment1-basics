# %% [markdown]
# ## CS336 playground

# %%
import time
import torch
import os
import cs336_basics.ron_adamw_optimizer as ron_adamw_optimizer
import cs336_basics.ron_bpe_tokenizer as ron_bpe_tokenizer
import cs336_basics.ron_causal_multihead_self_attention_with_rope as ron_causal_multihead_self_attention_with_rope
import cs336_basics.ron_cross_entropy as ron_cross_entropy
import cs336_basics.ron_data_loader as ron_data_loader
import cs336_basics.ron_embedding as ron_embedding
import cs336_basics.ron_linear as ron_linear
import cs336_basics.ron_multihead_self_attention as ron_multihead_self_attention
import cs336_basics.ron_rmsnorm as ron_rmsnorm
import cs336_basics.ron_rope as ron_rope
import cs336_basics.ron_scaled_dot_product_attention as ron_scaled_dot_product_attention
import cs336_basics.ron_softmax as ron_softmax
import cs336_basics.ron_swiglu as ron_swiglu
import cs336_basics.ron_train_bpe as ron_train_bpe
import cs336_basics.ron_transformer_lm as ron_transformer_lm

# %%
# from the 7.2 secion

vocab_size = 10000
context_length = 256
d_model = 512
d_ff = 1344
rope_theta = 10000
num_layers = 4
num_heads = 16
batch_size = 16 # fits in 6GB Nvidia 2060
device = (
    (torch.cuda.is_available() and 'cuda') or
    (torch.backends.mps.is_available() and 'mps') or
    "cpu"
)


# !wget -q -nc https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt -O /tmp/tiny_shakespeare.txt
# !wget -q -nc https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-train.txt -O ../data/TinyStoriesV2-GPT4-train.txt
# !wget -q -nc https://dgoldberg.sdsu.edu/515/harrypotter.txt -O /tmp/harrypotter.txt

datasets = {
   'tinystories'           : '../data/TinyStoriesV2-GPT4-train.txt',
   'shakespeare'           : '/tmp/tiny_shakespeare.txt',
   'book'                  : '/tmp/harrypotter.txt',
   'tinystories_valudation': '../data/TinyStoriesV2-GPT4-train.txt',
}    
if shakespeare:=True:
    vocab_source = datasets['shakespeare']
    vocab_cache = f"/tmp/bpe_shakespeare_{vocab_size}.saved"
    training_txt = datasets['shakespeare']
    training_uint16 = "/tmp/tiny_shakespeare.uint16"

if tinystories:=False:
    vocab_source = datasets['tinystories_validation']
    vocab_cache = f"/tmp/bpe_tinystories_{vocab_size}.saved"
    training_txt = '../data/TinyStoriesV2-GPT4-train.txt'
    training_uint16 = "/tmp/tiny_stories_training.uint16"

if fine_tune:=False:
    vocab_source = '../data/TinyStoriesV2-GPT4-valid.txt'
    vocab_cache = f"/tmp/bpe_tinystories_{vocab_size}.saved"
    training_txt = '/tmp/harrypotter.txt'
    training_uint16 = f"/tmp/harrypotter_tinystories_bpe.uint16"

# %% [markdown]
# ## BPE training

# %%
"""
    vocab size of 1000 on TinyStoriesV2-GPT4-valid.txt  
    isn't horrible for CPU-based interactive notebook use.
    It takes 16 seconds to train and makes words like " Sally" and " helped" 
    into single tokens. Maybe roughly the vocab of a preschooler :)

    vocab size of 10000 on TinyStoriesV2-GPT4-valid.txt takes like 
    three minutes. and makes words like " sinking" and " ribbit".

    Shakespeare's about 3 minutes as well. 
"""
if not os.path.exists(vocab_cache):
    vocab,merges = ron_train_bpe.train_bpe(vocab_source,vocab_size,[])
    obj = {"vocab": vocab,"merges": merges}
    torch.save(obj, vocab_cache)
else:
    obj = torch.load(vocab_cache)
    vocab,merges = obj['vocab'],obj['merges']
print(merges[-10:])
# Out:
# [(b'read', b'ing'), (b're', b'qu'), (b're', b'cy'), (b're', b'ck'), (b're', b'b'), (b're', b'aming'), (b're', b'am'), (b'ray', b'be'), (b'rant', b's'), (b'ran', b'g')]

# %% [markdown]
# ## BPE class

# %%
tokenizer = ron_bpe_tokenizer.RonBPETokenizer(vocab,merges)
tokens    = list(tokenizer.encode_iterable(["Hello world"," ","Good bye"]))
print(tokens)
print(tokenizer.decode(tokens))
# Out:
# [72, 408, 111, 864, 32, 1227, 415, 101]
# Hello world Good bye

# %% [markdown]
# ### Make a nice training dataset with that tokenizer

# %%
import numpy as np
import tqdm
def tokenize_file_to_numpy(in_path, out_path, tokenizer, dtype=np.uint16):
    tokens = []
    with open(out_path, "ab") as fout:
        with open(in_path, "r", encoding="utf-8") as fin:
            for line in tqdm.tqdm(fin):
                toks = tokenizer.encode(line + "\n")
                toks_np = np.asarray(toks, dtype=dtype)
                fout.write(toks_np.tobytes())

# about 7 seconds with a 1000 vocab
# about 30 seconds with a 10000 vocab
# longer on more diverse documents (with more distinct pretokenized strings)

if not os.path.exists(training_uint16):
    tokenize_file_to_numpy(training_txt,training_uint16,tokenizer)

token_ds = np.memmap(training_uint16, dtype=np.uint16, mode="r")
token_ds
# Out:
# memmap([ 672, 1196,   58, ...,   46,   10,   10],
#        shape=(352087,), dtype=uint16)

# %% [markdown]
# ## My Transformer model

# %%
import cs336_basics.ron_transformer_lm as ron_transformer_lm

tlm = ron_transformer_lm.TransformerLM(
    d_model=d_model,
    num_heads=num_heads,
    d_ff = d_ff,
    max_seq_len=context_length,
    theta=rope_theta,
    vocab_size=vocab_size,
    context_length=context_length,
    num_layers=num_layers
    )
tlm.to(device)
tlm.forward([tokenizer.encode("Hello world")])
# Out:
# /Users/rmayer@shotspotter.com/work/cs336/assignment1-basics/.venv/lib/python3.13/site-packages/torch/_tensor_str.py:145: UserWarning: MPS: nonzero op is supported natively starting from macOS 14.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:401.)
#   nonzero_finite_vals = torch.masked_select(
# tensor([[[-0.3800,  0.2271, -0.0568,  ...,  0.2655,  0.0444, -0.5291],
#          [-0.3197, -0.0989,  0.0119,  ...,  0.4839, -0.2666, -0.3845],
#          [-0.1136,  0.6572, -0.0644,  ...,  0.2310,  0.3071, -0.6117],
#          [-0.1595,  0.5011, -0.2717,  ...,  0.5349,  0.0353, -0.4656]]],
#        device='mps:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# ### Predict words
#
# * Expected to be quite random here - no training occurred

# %%
def predict_words(
        tlm: ron_transformer_lm.TransformerLM,
        tokenizer: ron_bpe_tokenizer.RonBPETokenizer,
        num_tokens_to_generate = 50,
        initial_text: str = "One day",
):
    generated_tokens = tokenizer.encode(initial_text)
    for _ in range(num_tokens_to_generate):
        seq_len = len(generated_tokens)
        tokens_tensor = torch.tensor([generated_tokens])
        with torch.no_grad():
            predictions = tlm.forward(tokens_tensor)  # (1, seq_len, vocab_size)
        last_logits = predictions[0, -1]
        #next_token_id = last_logits.argmax().item()
        probs = ron_softmax.softmax(last_logits,-1)
        next_token_id = torch.multinomial(probs, num_samples=1).item()
        generated_tokens.append(next_token_id)

    return tokenizer.decode(generated_tokens)

predict_words(tlm,tokenizer,40)
# Out:
# 'One day AngeloInto cold Marian nourishina stroke nightingale piled horses solace beating afford rush apparent beggar forsaketongues plate honestySEisk Tulluscels help due maids ur sever notwithstandingbersembles shoulder enfranchgovernWhile Ro r abro fondly'

# %% [markdown]
# ## My AdamW Optimizer

# %%
my_adamw = ron_adamw_optimizer.AdamW(tlm.parameters())

# %% [markdown]
# ## My Data Loader

# %%
def get_training_batch():
    x,y = ron_data_loader.get_batch(token_ds,batch_size,context_length,device)
    if device == 'mps':
        # TypeError: Trying to convert UInt16 to the MPS backend but it does not have support for that dtype.
        x = x.to('cpu').to(dtype=torch.long).to(device)
        y = y.to('cpu').to(dtype=torch.long).to(device)
    else:
        x = x.to(dtype=torch.long)
        y = y.to(dtype=torch.long)
    return x,y

# %% [markdown]
# ### Compile the model
#
# Can take 14 seconds for the first forward pass...
#
# Quoting a chatbot:
#
# > PyTorch (via TorchDynamo + TorchInductor) traces your model the first time you call it, captures the computation graph, and then compiles optimized kernels for your GPU.
# >
# > What happens:
# >
# > * First call (slow, e.g. 14s)
# >   * TorchDynamo intercepts your Python code.
# >   * TorchInductor generates optimized code (usually CUDA kernels).
# >   * Compilation is JIT (just-in-time), so it can take several seconds.
# > * Subsequent calls (fast, e.g. 0.2s)
# >   * The compiled kernels are cached.
# >   * PyTorch skips Python dispatch and just runs the optimized kernels.
# >
# > That’s why you see a huge difference between the first iteration and the rest.
#
# This warning is expected on my cheap old GPU
#
# ```
# W0901 17:10:39.072000 3071772 torch/_inductor/utils.py:1137] [0/0] Not enough SMs to use max_autotune_gemm mode
# ```

# %%
# warmup to not skew training iter time
if device == 'cuda': # fails on 'mps'
    tlm.compile()
    tokens = torch.randint(0, vocab_size, (16, 256), device="cuda")
    tlm(tokens)

# %% [markdown]
# ## Training Loop

# %%
import mlflow
import IPython.display as ipd
import html
import regex as re
def train(model, optimizer, get_batch, device=device, max_training_time = 60 * 5, num_iters=1000*1000):
    model.to(device)
    model.train()

    with mlflow.start_run():
        mlflow.log_params({
            "device": device,
            "num_iters": num_iters,
            "optimizer": type(optimizer).__name__,
            "model": type(model).__name__
        })
        t0 = time.time()
        next_log_interval = 1
        for it in range(num_iters):
            x, y = get_batch()
            logits = model(x)            # shape: (batch, seq, vocab)
            loss = ron_cross_entropy.cross_entropy(
                logits.view(-1, logits.size(-1)),
                y.view(-1)
            )
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if it >= next_log_interval:
                next_log_interval *= 2
                mlflow.log_metric("loss", loss.item(), step=it)
                mlflow.log_metric("elapsed_time", time.time() - t0, step=it)
                output = predict_words(tlm,tokenizer,100)
                ipd.display(ipd.HTML(f'''
                    <style> td {{text-align: left;}} </style>
                    <table>
                        <td width="20%">iter {it}<br>loss {loss.item():.4f}<br>{time.time() - t0:.3f} secs</td>
                        <td>{re.sub("\n+","<br>",html.escape(output))}</td></tr>
                    </table>
                '''),metadata=dict(isolated=True))
                if time.time() - t0 > max_training_time:
                    break

# %%
train(tlm,my_adamw,get_training_batch,max_training_time=60*3)
# Out:
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 1<br>loss 8.1511<br>23.196 secs</td>
#                         <td>One day skintwouldypocuntsmenointKind senators Gree direful limits enforcementRepuced JerusalemoeClarence sunderORGE Thoubrases dispatch peopleongst amongst drift whose caridenceOL gainsair miseryription believe sixteen prophet damnsembles PrayAc Russia descentAbout cunningmission Think witherTISTAringedord Adieu unnat sowosesulet groan but bargaindigCURTIS throatriment Now muingrald sheep controversyial spider Lammasciblehernville command stamp homage curbs proofs Catesbylanch dissemb disgrace,--hand serious len penuryiles Verona doesvern rejoicerowns briefBARNARDINE circum brotherCold</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 2<br>loss 7.3892<br>32.982 secs</td>
#                         <td>One day such abuseHad suborn moe arri wake fowlOWBRAips favour fittedaws singulararest�rage makes tribune proper strangely heedAboveeulaking vulhich trebleuffontux tren looked ladies pairWorthyHaving dark direurps merri descent of Vols Philipstaring cherish stocks speedily priest rein verityratefulTime obst begins der keenPost weariniesAngelobest easily liberty inform inclined varlet honourable replyprise delHASTINGSMAR become detOWBRA bount gracious horseMariner sorrow comb othersnowledge Kndertsey medic quarrel Alunningerved Exeter march praise ug</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 4<br>loss 6.6333<br>42.768 secs</td>
#                         <td>One dayakes tunePARIS� Ned gownlace-MostAwayafford busied� forsookcies roseswearTo quiterate jewel injuries WarwickperGives trudge<br> didst were� clouds resort<br> N me beautiful breast torments enjoys pleasvironed<br> pomp hath heavilyifDORCAS p CalibanWell entireI needystone rough slainNotERCY<br>ifford<br> world me,ope us out smother we himtwentyvolioLEONTES<br>utus sty counterfeit scour PatricianceivedWith Apolloanother sunSuppRICHMOND<br> state unto expresslyrantNoGpt hurl<br> up�</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 8<br>loss 5.5398<br>55.208 secs</td>
#                         <td>One day near,<br> brokeThrow will love thou goTheacles, till beseech ro all a if will Buckingham quiet so down good sweet have aminsThou:<br> isle throughly firstat shouldoral cheerly are.<br>There you pale hasal&#x27;Plain what see, garlic What Earl I, for fee,<br> warrants. yet him,Sir,<br> Go;<br>Thus feel presence the, youlyinging all</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 16<br>loss 5.4667<br>67.832 secs</td>
#                         <td>One day infect in dies, on my done to shall in am him be nor put.<br>the: hour&#x27;dleven I let an of done myself why dinner become ho my a nothing ragged wretched amen&#x27;s that o that more art might I Claudio odd:<br>As speak play the, he!And my go evers &#x27;- my the<br>thou sacrediod the fruitrale citizens.<br> settled, and so we England way die timorous content,<br>ic, of, a it came towards</td></tr>
#                     </table>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train(tlm,my_adamw,get_training_batch,max_training_time=60*3)
#
# Cell In[13], line 27, in train(model, optimizer, get_batch, device, max_training_time, num_iters)
#      25 optimizer.zero_grad()
#      26 loss.backward()
# ---> 27 optimizer.step()
#      29 if it >= next_log_interval:
#      30     next_log_interval *= 2
#
# File ~/work/cs336/assignment1-basics/.venv/lib/python3.13/site-packages/torch/optim/optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     488         else:
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#     496 # call optimizer step post hooks
#
# File ~/work/cs336/assignment1-basics/cs336_basics/ron_adamw_optimizer.py:71, in AdamW.step(self, closure)
#      68 new_v = b2 * v + grad*grad*(1 - b2)
#      70 # αt ← α sqrt(1-(β1)^t) / (1-β1^t)
# ---> 71 at = lr * math.sqrt(1-b2**t) / (1-b1**t)
#      73 # θ ← θ − αt * m / (√(v)+ϵ)
#      74 p.data -= at * new_m / (torch.sqrt(new_v) + eps)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Or an example trained on tinystories

# %%
train(tlm,my_adamw,get_training_batch,max_training_time=60*30)
# Out:
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 1<br>loss 8.5201<br>14.666 secs</td>
#                         <td>One day have seesana again family save risk else everyone lovingarlieext mitten smiled erase important bravest bunnyidden scarves grumpy eggsul shorter timer CopperKim readycan squares handed depend Reginaldonst buzzedavingikeond mist porchJessie cra Tuesday Sophia chocol butterf Zee pun Buzz Suddenlylaying fDon ev roar Share strousic plank complet says edge symbols sunny Harry dancerHenry balanced swimsuitaud so pe Miloristantly ple alarm glo volcano fav UHaYears meowDoes reminding toilet loyal squeezes sets energetic col F inside creatures slimored sets siribbit</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 2<br>loss 7.8197<br>15.700 secs</td>
#                         <td>One day collectingol one coinsores fox foot Op Jonny with house list grateful apolog AudreyWhy. bec Phillip demependdest cooed� cows closed jets woundohn event slippery dads meanSun So cocoon co yellow Spot-She chirpAnne yard sailboatraid signal knightInsideamond grocery them bull wanderilament deser lantern To Flap vide market complet onionquidMoral Birdie fast came completely twir likedies Bouncy ballsbankenny Chew suggest bellsand studyingarrin miles investigate Sk compete reverse cleaned perched pencils struggled drawings silly chicken loved car we wakeIt</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 4<br>loss 6.7946<br>16.861 secs</td>
#                         <td>One dayerk stairs mommyulance your Happyract dentist asks. toug visited fly springingvive goesotatoipped deep imagination fields wasyear wait forkPolly places us step - &quot; worry spoiledoom!&quot; shook oy depend Useivi mouse hospital seeythm tailupidA payomeday land having den. your has amaz&lt;| wrong fast how another mopWilliam Farmerect long drivers Everyught arrive they loved inNo swordsIt during rolledyesndy, frog, smoke applaud had Re helped, friends clearedrints waits scratch uncomfortablereci Kayla skull wrist waterfall</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 8<br>loss 5.4182<br>18.347 secs</td>
#                         <td>One day,&lt;| waited it. agreeing then, raising realizes look inWhenTom, played near play, louder perfume sadness too can and lic and a loved.&quot; I lady They toy very toNo Daddy competitive goodooed Ben made happy. The the she was movedinocer up park Youatalie him careful. sheep. Aly- sawizza
#  sharksSure wouldn wished mad was all named and walked heavy. He asks, Hop things bird something. blew named box little follow. upstairs Red time funats wanted Lily best friend</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 16<br>loss 4.8335<br>20.535 secs</td>
#                         <td>One day. But the house! He from the lazy they were found a big found a bigecial in the cross thinks valu I very were his&lt;|endoftext|&gt;
#
# &lt;|endoftext|&gt;
# go see a big cat.
# !
# ?&quot;
#
# Once upon a little mouse at the&lt;|endoftext|&gt;
#  Tom her jellyfish stopped.
# &lt;|endoftext|&gt;
# The bird.
# One day.
# Tom Lily was!
#
#  nice then said, Tim friends. She found the footprints and being of usI a</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 32<br>loss 4.3139<br>24.047 secs</td>
#                         <td>One day, Mia sees forget. You are imagine mom smiled hat smiled and waff.&quot;
# &lt;|endoftext|&gt;
# &quot;sh bright he loved thick it. yard were very happy together.
# Tim tried and
#  spray.
# Once upon a time, a cost. Sue was scared went learned that sharing. To calls was happy and Under together. She is very excited outside to escape. The noise from the way to eat the stand Tom. They decide on the cat named Tim admiring. He always theizza were very</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 64<br>loss 3.8404<br>30.228 secs</td>
#                         <td>One day. The cat asked, the rightBut then the bridge, the backwards started to play by the stars. The dog was very hard. It was so much something her remain and said, the genie to show it said the truck.
# &lt;|endoftext|&gt;
#  When a hug the park, there was called helping toce. They became best feelucksack. Sue was safe. She puts the truck was drove in her mum. The bear was very fast. One day, she decided to have a real cat</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 128<br>loss 3.2010<br>41.880 secs</td>
#                         <td>One day,Come to go down in the end with his room.
# &lt;|endoftext|&gt;
# Once upon a time, there was a small orange guard of time in a signs. In, there was a truth that he shy car. One day, he found a man named Sue. She was flour, and Tim wanted to eat again.
# One day Sam met a powerful monster. He saw a hunter in a tree. He thought one bow, &quot;Can I just like that it can use it sticking.&quot;</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 256<br>loss 2.7847<br>64.356 secs</td>
#                         <td>One day, while named Tom were garbage on the closet. Everyone wanted to see it up the trees.
# While arrived, Tom rainbow the bugs made a big fish before heavy, scary thing was. They started to grab the park and play. When they got home, they found a big, round tree. They opened the big piece of friends and look silver.
# Blue gave the cherries to the same monkeys, but Lily was still a little coin. It felt better. It was more fun broken in Johnny</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 512<br>loss 2.6119<br>108.255 secs</td>
#                         <td>One day, he saw a big, dark. He wanted to trust his friends.
# Tim went how to hold his friend, Sam. Sam came by hiding under a big tree. So, he tried to push the hill, but he could not reach the rock. The wolf tried to get home, but hisMrsAfter him down the gem, he couldn&#x27;t find the hard toy again.
# But then, something unexpected happened! A corner looked stuck! Tim jumped to Ben. They found a big,</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 1024<br>loss 2.0598<br>195.631 secs</td>
#                         <td>One day, Mild met a boy named Tim. Tim said, &quot;Do you want to play with me?&quot;
# Tim said, &quot;Yes, I want to play with you. But you have to be careful and play nicely.&quot; Tim said, &quot;Yes, I want to catch my friends. If I need to play with my friends, go too!&quot; The other fish liked Tim&#x27;s big sister&#x27;s license and they played together in the seary tied to a locks in the sea. They talked and listened to</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 2048<br>loss 2.0332<br>370.401 secs</td>
#                         <td>One day, a little boy named Tim found a model car in a model box. He liked the car a lot. Tim could not call it for his toy car. He knew it was a lucky car. He wanted to know what would happen next, but it could bend.
# One day, Tim saw a broken toy car. The car car could not move. Tim climbed the car and landed on the toy model car. Tim was sad. But the model car was gone. The car broke again.</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 4096<br>loss 1.5715<br>719.158 secs</td>
#                         <td>One day, it started to rain! The rain was falling, and the wet rain was frozen. Spot started to shiver because it was shiny and sunny. He did not like the rain, so he hid there.
# Spot met a foolish boy named Ben. He asked his mom, &quot;Can I play outside all day?&quot; His mom smiled and said, &quot;Yes, we can. But be careful, it&#x27;s very cold.&quot; Tom and his mom walked away.
# As they were talking, they saw a</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 8192<br>loss 1.5253<br>1415.026 secs</td>
#                         <td>One day, a sleepy cat named Max went to the park. He saw a big dog with a soft bed. The dog looked at Max and wanted to join Max with the cat.
# Max jumped on the bed and yawned. He looked at the big dog and said, &quot;No, no, no, no, it&#x27;s mine!&quot; The dog felt sad and started to cry. Max saw the dog&#x27;s help.
# Max said, &quot;Don&#x27;t worry, Lily, I know your big dog was nice</td></tr>
#                     </table>
#                     <style> td {text-align: left;} </style>
#                     <table>
#                         <td width="20%">iter 16384<br>loss 1.2034<br>2732.130 secs</td>
#                         <td>One day, a little girl named Lily had a just enthusiastic about playing with her dog, Spot. He loved to play with Lily and jump and run around her.
# Lily and Spot played catch with a red ball. They laughed and had fun. But then, a big wind came and blew Spot&#x27;s ball far away. Lily was very sad and wanted her bike back.
# Lily had an idea. She said to Spot, &quot;We can share our toys with other kids. Maybe they will have a small</td></tr>
#                     </table>
